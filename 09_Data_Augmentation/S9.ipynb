# %% [markdown]
# # Imports
# Importing necessary packages and modules

# %%
# %matplotlib inline

import random

from torchsummary import summary

from cuda import initialize_cuda
from data.dataset import CIFAR10
from model import ResNet18
from model.utils.loss import cross_entropy_loss
from model.utils.optimizers import sgd_optimizer
from model.utils.callbacks import lr_scheduler
from gradcam import GradCAMView
from train import train
from evaluate import val
from result import plot_metric, save_and_show_result

# %% [markdown]
# # Configuration
#
# Set various parameters and hyperparameters

# %%
class Args:

    # Data Loading
    # ============

    train_batch_size = 64
    val_batch_size = 64
    num_workers = 4

    # Augmentation
    # ============
    horizontal_flip_prob = 0.2
    vertical_flip_prob = 0.0
    gaussian_blur_prob = 0.0
    rotate_degree = 20
    cutout = 0.3

    # Training
    # ========
    random_seed = 1
    epochs = 50
    learning_rate = 0.01
    momentum = 0.9
    lr_step_size = 25
    lr_gamma = 0.1

    # Evaluation
    # ==========
    sample_count = 25

# %% [markdown]
# ## Set Seed and Get GPU Availability

# %%
# Initialize CUDA and set random seed
cuda, device = initialize_cuda(Args.random_seed)
# Out:
# GPU Available? True

# %% [markdown]
# ## Download Dataset
#
# Importing the CIFAR-10 class to download dataset and create data loader

# %%
dataset = CIFAR10(
    train_batch_size=Args.train_batch_size,
    val_batch_size=Args.val_batch_size,
    cuda=cuda,
    num_workers=Args.num_workers,
    horizontal_flip_prob=Args.horizontal_flip_prob,
    vertical_flip_prob=Args.vertical_flip_prob,
    gaussian_blur_prob=Args.gaussian_blur_prob,
    rotate_degree=Args.rotate_degree,
    cutout=Args.cutout
)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /src/D/Research/EVA5-Vision-Squad/S9/data/cifar10/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /src/D/Research/EVA5-Vision-Squad/S9/data/cifar10/cifar-10-python.tar.gz to /src/D/Research/EVA5-Vision-Squad/S9/data/cifar10
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Training and Validation Dataloaders
# This is the final step in data preparation. It sets the dataloader arguments and then creates the dataloader

# %%
# Create train data loader
train_loader = dataset.loader(train=True)

# Create val data loader
val_loader = dataset.loader(train=False)

# %% [markdown]
# # Model Architecture and Summary

# %%
model = ResNet18().to(device)  # Create model
summary(model, dataset.image_size)  # Display model summary
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %% [markdown]
# # Model Training and Validation

# %%
losses = []
accuracies = []
correct_samples = []
incorrect_samples = []

criterion = cross_entropy_loss()  # Create loss function
optimizer = sgd_optimizer(model, Args.learning_rate, Args.momentum)  # Create optimizer
scheduler = lr_scheduler(optimizer, Args.lr_step_size, Args.lr_gamma)
last_epoch = False

for epoch in range(1, Args.epochs + 1):
    print(f'Epoch {epoch}:')
    if epoch == Args.epochs:
        last_epoch = True
    train(model, train_loader, device, optimizer, criterion)
    scheduler.step()
    val(
        model, val_loader, device, criterion, losses, accuracies,
        correct_samples, incorrect_samples, Args.sample_count, last_epoch=last_epoch
    )
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# Epoch 1:
# Loss=0.87 Batch_ID=781 Accuracy=49.97: 100%|██████████| 782/782 [00:25<00:00, 30.21it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0146, Accuracy: 6692/10000 (66.92%)
#
# Epoch 2:
# Loss=1.06 Batch_ID=781 Accuracy=68.95: 100%|██████████| 782/782 [00:26<00:00, 29.92it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0125, Accuracy: 7270/10000 (72.70%)
#
# Epoch 3:
# Loss=1.44 Batch_ID=781 Accuracy=75.57: 100%|██████████| 782/782 [00:26<00:00, 29.75it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0102, Accuracy: 7702/10000 (77.02%)
#
# Epoch 4:
# Loss=0.46 Batch_ID=781 Accuracy=79.35: 100%|██████████| 782/782 [00:26<00:00, 29.15it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0099, Accuracy: 7867/10000 (78.67%)
#
# Epoch 5:
# Loss=1.31 Batch_ID=781 Accuracy=82.30: 100%|██████████| 782/782 [00:26<00:00, 29.04it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0079, Accuracy: 8308/10000 (83.08%)
#
# Epoch 6:
# Loss=0.50 Batch_ID=781 Accuracy=84.27: 100%|██████████| 782/782 [00:27<00:00, 28.73it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0085, Accuracy: 8236/10000 (82.36%)
#
# Epoch 7:
# Loss=0.35 Batch_ID=781 Accuracy=85.88: 100%|██████████| 782/782 [00:27<00:00, 28.71it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0074, Accuracy: 8430/10000 (84.30%)
#
# Epoch 8:
# Loss=0.22 Batch_ID=781 Accuracy=86.97: 100%|██████████| 782/782 [00:27<00:00, 28.63it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0089, Accuracy: 8253/10000 (82.53%)
#
# Epoch 9:
# Loss=0.75 Batch_ID=781 Accuracy=88.39: 100%|██████████| 782/782 [00:27<00:00, 28.40it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0067, Accuracy: 8619/10000 (86.19%)
#
# Epoch 10:
# Loss=0.39 Batch_ID=781 Accuracy=89.41: 100%|██████████| 782/782 [00:27<00:00, 28.49it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0064, Accuracy: 8640/10000 (86.40%)
#
# Epoch 11:
# Loss=0.39 Batch_ID=781 Accuracy=90.42: 100%|██████████| 782/782 [00:27<00:00, 28.46it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0066, Accuracy: 8672/10000 (86.72%)
#
# Epoch 12:
# Loss=0.83 Batch_ID=781 Accuracy=91.12: 100%|██████████| 782/782 [00:27<00:00, 28.33it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0077, Accuracy: 8551/10000 (85.51%)
#
# Epoch 13:
# Loss=0.21 Batch_ID=781 Accuracy=91.62: 100%|██████████| 782/782 [00:27<00:00, 28.31it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0072, Accuracy: 8595/10000 (85.95%)
#
# Epoch 14:
# Loss=0.34 Batch_ID=781 Accuracy=92.29: 100%|██████████| 782/782 [00:27<00:00, 28.29it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0069, Accuracy: 8646/10000 (86.46%)
#
# Epoch 15:
# Loss=0.30 Batch_ID=781 Accuracy=92.99: 100%|██████████| 782/782 [00:27<00:00, 28.76it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0066, Accuracy: 8727/10000 (87.27%)
#
# Epoch 16:
# Loss=0.07 Batch_ID=781 Accuracy=93.45: 100%|██████████| 782/782 [00:27<00:00, 28.56it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0072, Accuracy: 8652/10000 (86.52%)
#
# Epoch 17:
# Loss=0.52 Batch_ID=781 Accuracy=93.77: 100%|██████████| 782/782 [00:27<00:00, 28.55it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0064, Accuracy: 8806/10000 (88.06%)
#
# Epoch 18:
# Loss=0.68 Batch_ID=781 Accuracy=94.07: 100%|██████████| 782/782 [00:26<00:00, 28.97it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0064, Accuracy: 8817/10000 (88.17%)
#
# Epoch 19:
# Loss=0.02 Batch_ID=781 Accuracy=94.60: 100%|██████████| 782/782 [00:27<00:00, 28.56it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0069, Accuracy: 8773/10000 (87.73%)
#
# Epoch 20:
# Loss=0.00 Batch_ID=781 Accuracy=94.98: 100%|██████████| 782/782 [00:27<00:00, 28.58it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0064, Accuracy: 8835/10000 (88.35%)
#
# Epoch 21:
# Loss=0.04 Batch_ID=781 Accuracy=95.23: 100%|██████████| 782/782 [00:27<00:00, 28.59it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0060, Accuracy: 8932/10000 (89.32%)
#
# Epoch 22:
# Loss=0.08 Batch_ID=781 Accuracy=95.34: 100%|██████████| 782/782 [00:27<00:00, 28.77it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0067, Accuracy: 8778/10000 (87.78%)
#
# Epoch 23:
# Loss=0.64 Batch_ID=781 Accuracy=95.55: 100%|██████████| 782/782 [00:27<00:00, 28.41it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0061, Accuracy: 8907/10000 (89.07%)
#
# Epoch 24:
# Loss=0.08 Batch_ID=781 Accuracy=95.64: 100%|██████████| 782/782 [00:27<00:00, 28.57it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0064, Accuracy: 8864/10000 (88.64%)
#
# Epoch 25:
# Loss=0.30 Batch_ID=781 Accuracy=95.84: 100%|██████████| 782/782 [00:27<00:00, 28.42it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0063, Accuracy: 8911/10000 (89.11%)
#
# Epoch 26:
# Loss=0.20 Batch_ID=781 Accuracy=97.23: 100%|██████████| 782/782 [00:27<00:00, 28.43it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9051/10000 (90.51%)
#
# Epoch 27:
# Loss=0.57 Batch_ID=781 Accuracy=97.85: 100%|██████████| 782/782 [00:27<00:00, 28.43it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9076/10000 (90.76%)
#
# Epoch 28:
# Loss=0.05 Batch_ID=781 Accuracy=98.00: 100%|██████████| 782/782 [00:27<00:00, 28.45it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9110/10000 (91.10%)
#
# Epoch 29:
# Loss=0.05 Batch_ID=781 Accuracy=98.10: 100%|██████████| 782/782 [00:27<00:00, 28.63it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9118/10000 (91.18%)
#
# Epoch 30:
# Loss=0.05 Batch_ID=781 Accuracy=98.25: 100%|██████████| 782/782 [00:27<00:00, 28.41it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9111/10000 (91.11%)
#
# Epoch 31:
# Loss=0.02 Batch_ID=781 Accuracy=98.33: 100%|██████████| 782/782 [00:27<00:00, 28.70it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9109/10000 (91.09%)
#
# Epoch 32:
# Loss=0.29 Batch_ID=781 Accuracy=98.39: 100%|██████████| 782/782 [00:27<00:00, 28.62it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9124/10000 (91.24%)
#
# Epoch 33:
# Loss=0.01 Batch_ID=781 Accuracy=98.38: 100%|██████████| 782/782 [00:27<00:00, 28.44it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9126/10000 (91.26%)
#
# Epoch 34:
# Loss=0.74 Batch_ID=781 Accuracy=98.44: 100%|██████████| 782/782 [00:27<00:00, 28.48it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9134/10000 (91.34%)
#
# Epoch 35:
# Loss=0.11 Batch_ID=781 Accuracy=98.49: 100%|██████████| 782/782 [00:27<00:00, 28.33it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9132/10000 (91.32%)
#
# Epoch 36:
# Loss=0.10 Batch_ID=781 Accuracy=98.48: 100%|██████████| 782/782 [00:27<00:00, 28.52it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9140/10000 (91.40%)
#
# Epoch 37:
# Loss=0.12 Batch_ID=781 Accuracy=98.50: 100%|██████████| 782/782 [00:27<00:00, 28.55it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9122/10000 (91.22%)
#
# Epoch 38:
# Loss=0.03 Batch_ID=781 Accuracy=98.58: 100%|██████████| 782/782 [00:27<00:00, 28.83it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9125/10000 (91.25%)
#
# Epoch 39:
# Loss=0.00 Batch_ID=781 Accuracy=98.57: 100%|██████████| 782/782 [00:27<00:00, 28.43it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9115/10000 (91.15%)
#
# Epoch 40:
# Loss=0.01 Batch_ID=781 Accuracy=98.57: 100%|██████████| 782/782 [00:27<00:00, 28.42it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9130/10000 (91.30%)
#
# Epoch 41:
# Loss=0.02 Batch_ID=781 Accuracy=98.71: 100%|██████████| 782/782 [00:27<00:00, 28.67it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9145/10000 (91.45%)
#
# Epoch 42:
# Loss=0.01 Batch_ID=781 Accuracy=98.65: 100%|██████████| 782/782 [00:27<00:00, 28.47it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0049, Accuracy: 9123/10000 (91.23%)
#
# Epoch 43:
# Loss=0.01 Batch_ID=781 Accuracy=98.61: 100%|██████████| 782/782 [00:27<00:00, 28.50it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9098/10000 (90.98%)
#
# Epoch 44:
# Loss=0.02 Batch_ID=781 Accuracy=98.70: 100%|██████████| 782/782 [00:27<00:00, 28.43it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9131/10000 (91.31%)
#
# Epoch 45:
# Loss=0.01 Batch_ID=781 Accuracy=98.76: 100%|██████████| 782/782 [00:27<00:00, 28.93it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9119/10000 (91.19%)
#
# Epoch 46:
# Loss=0.12 Batch_ID=781 Accuracy=98.74: 100%|██████████| 782/782 [00:27<00:00, 28.30it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9137/10000 (91.37%)
#
# Epoch 47:
# Loss=0.44 Batch_ID=781 Accuracy=98.73: 100%|██████████| 782/782 [00:27<00:00, 28.53it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9121/10000 (91.21%)
#
# Epoch 48:
# Loss=0.01 Batch_ID=781 Accuracy=98.80: 100%|██████████| 782/782 [00:27<00:00, 28.38it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0051, Accuracy: 9127/10000 (91.27%)
#
# Epoch 49:
# Loss=0.01 Batch_ID=781 Accuracy=98.86: 100%|██████████| 782/782 [00:27<00:00, 28.48it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0051, Accuracy: 9129/10000 (91.29%)
#
# Epoch 50:
# Loss=0.00 Batch_ID=781 Accuracy=98.82: 100%|██████████| 782/782 [00:27<00:00, 28.42it/s]
# Validation set: Average loss: 0.0050, Accuracy: 9111/10000 (91.11%)

# %% [markdown]
# ## Plotting Results

# %% [markdown]
# Plot changes in validation loss

# %%
plot_metric(losses, 'Loss')

# %% [markdown]
# Plot changes in validation accuracy

# %%
plot_metric(accuracies, 'Accuracy')

# %% [markdown]
# ### GradCAM

# %% [markdown]
# Let's display GradCAM of any random 2 correctly predicted samples

# %%
grad_cam = GradCAMView(
    model, ['layer1', 'layer2', 'layer3', 'layer4'],
    device, dataset.mean, dataset.std
)

images = [x['image'] for x in random.sample(correct_samples, 4)]
grad_cam(images, 'grad_cam')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2796: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Mode set to GradCAM.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Display Correct and Incorrect Predictions

# %%
save_and_show_result(correct_samples, incorrect_samples, dataset.classes)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
