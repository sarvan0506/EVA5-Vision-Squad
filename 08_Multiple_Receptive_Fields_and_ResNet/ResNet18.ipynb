# %% [markdown]
# # Imports
# Importing necessary packages and modules

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from torchsummary import summary

from data.dataset import CIFAR10
from model.resnet import ResNet18
from model.utils.loss import cross_entropy_loss
from model.utils.optimizers import sgd_optimizer
from model.utils.callbacks import lr_scheduler
from utils.cuda import initialize_cuda
from utils.train import train
from utils.evaluate import val
from utils.result import class_level_accuracy, plot_metric, save_and_show_result

# %% [markdown]
# # Configuration
#
# Set various parameters and hyperparameters

# %%
class Args:

    # Data Loading
    # ============

    train_batch_size = 64
    val_batch_size = 64
    num_workers = 4

    # Augmentation
    # ============
    rotation = 15

    # Training
    # ========
    random_seed = 1
    epochs = 50
    learning_rate = 0.01
    momentum = 0.9

    # Evaluation
    # ==========
    sample_count = 25

# %% [markdown]
# ## Set Seed and Get GPU Availability

# %%
# Initialize CUDA and set random seed
cuda, device = initialize_cuda(Args.random_seed)
# Out:
# GPU Available? True

# %% [markdown]
# ## Download Dataset
#
# Importing the CIFAR-10 class to download dataset and create data loader

# %%
dataset = CIFAR10(
    train_batch_size=Args.train_batch_size,
    val_batch_size=Args.val_batch_size,
    cuda=cuda,
    num_workers=Args.num_workers
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Data Visualization
# Let's see how our data looks like. This information will help us decide the transformations that can be used on the dataset.

# %%
# Fetch data
classes = dataset.classes()
sample_data, sample_targets = dataset.data()

# Set number of images to display
num_images = 4

# Display images with labels
fig, axs = plt.subplots(1, 4, figsize=(8, 8))
fig.tight_layout()

for i in range(num_images):
    axs[i].axis('off')
    axs[i].set_title(f'Label: {classes[sample_targets[i]]}')
    axs[i].imshow(sample_data[i])

# %% [markdown]
# ## Training and Validation Dataloaders
# This is the final step in data preparation. It sets the dataloader arguments and then creates the dataloader

# %%
# Create train data loader
train_loader = dataset.loader(train=True)

# Create val data loader
val_loader = dataset.loader(train=False)

# %% [markdown]
# # Model Architecture and Summary

# %%
model = ResNet18().to(device)  # Create model
summary(model, dataset.image_size())  # Display model summary
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %% [markdown]
# # Model Training and Validation

# %%
losses = []
accuracies = []
correct_samples = []
incorrect_samples = []

criterion = cross_entropy_loss()  # Create loss function
optimizer = sgd_optimizer(model, Args.learning_rate, Args.momentum)  # Create optimizer
last_epoch = False

for epoch in range(1, Args.epochs + 1):
    print(f'Epoch {epoch}:')
    if epoch == Args.epochs:
        last_epoch = True
    train(model, train_loader, device, optimizer, criterion)
    optimizer.step()
    val(
        model, val_loader, device, criterion, losses, accuracies,
        correct_samples, incorrect_samples, Args.sample_count, last_epoch=last_epoch
    )
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# Epoch 1:
# Loss=0.95 Batch_ID=781 Accuracy=72.92: 100%|██████████| 782/782 [00:27<00:00, 28.66it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0135, Accuracy: 7078/10000 (70.78%)
#
# Epoch 2:
# Loss=0.80 Batch_ID=781 Accuracy=80.64: 100%|██████████| 782/782 [00:27<00:00, 28.32it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0115, Accuracy: 7595/10000 (75.95%)
#
# Epoch 3:
# Loss=0.18 Batch_ID=781 Accuracy=85.43: 100%|██████████| 782/782 [00:28<00:00, 27.81it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0094, Accuracy: 8013/10000 (80.13%)
#
# Epoch 4:
# Loss=0.30 Batch_ID=781 Accuracy=89.55: 100%|██████████| 782/782 [00:28<00:00, 27.50it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0107, Accuracy: 7939/10000 (79.39%)
#
# Epoch 5:
# Loss=0.54 Batch_ID=781 Accuracy=92.44: 100%|██████████| 782/782 [00:28<00:00, 27.35it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0122, Accuracy: 7864/10000 (78.64%)
#
# Epoch 6:
# Loss=0.31 Batch_ID=781 Accuracy=94.51: 100%|██████████| 782/782 [00:28<00:00, 27.47it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0124, Accuracy: 7913/10000 (79.13%)
#
# Epoch 7:
# Loss=0.24 Batch_ID=781 Accuracy=96.27: 100%|██████████| 782/782 [00:28<00:00, 27.64it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0156, Accuracy: 7840/10000 (78.40%)
#
# Epoch 8:
# Loss=0.50 Batch_ID=781 Accuracy=97.15: 100%|██████████| 782/782 [00:28<00:00, 27.56it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0133, Accuracy: 8068/10000 (80.68%)
#
# Epoch 9:
# Loss=0.26 Batch_ID=781 Accuracy=97.13: 100%|██████████| 782/782 [00:26<00:00, 29.25it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0165, Accuracy: 7791/10000 (77.91%)
#
# Epoch 10:
# Loss=0.38 Batch_ID=781 Accuracy=98.07: 100%|██████████| 782/782 [00:27<00:00, 28.86it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0134, Accuracy: 8153/10000 (81.53%)
#
# Epoch 11:
# Loss=0.00 Batch_ID=781 Accuracy=98.58: 100%|██████████| 782/782 [00:27<00:00, 28.32it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0119, Accuracy: 8303/10000 (83.03%)
#
# Epoch 12:
# Loss=0.00 Batch_ID=781 Accuracy=99.54: 100%|██████████| 782/782 [00:27<00:00, 28.54it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0130, Accuracy: 8329/10000 (83.29%)
#
# Epoch 13:
# Loss=0.03 Batch_ID=781 Accuracy=99.71: 100%|██████████| 782/782 [00:26<00:00, 29.64it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0124, Accuracy: 8357/10000 (83.57%)
#
# Epoch 14:
# Loss=0.04 Batch_ID=781 Accuracy=99.68: 100%|██████████| 782/782 [00:27<00:00, 28.82it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0129, Accuracy: 8405/10000 (84.05%)
#
# Epoch 15:
# Loss=0.01 Batch_ID=781 Accuracy=99.72: 100%|██████████| 782/782 [00:26<00:00, 29.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0137, Accuracy: 8387/10000 (83.87%)
#
# Epoch 16:
# Loss=0.00 Batch_ID=781 Accuracy=99.74: 100%|██████████| 782/782 [00:27<00:00, 27.99it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0134, Accuracy: 8406/10000 (84.06%)
#
# Epoch 17:
# Loss=0.09 Batch_ID=781 Accuracy=99.85: 100%|██████████| 782/782 [00:28<00:00, 27.84it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0140, Accuracy: 8373/10000 (83.73%)
#
# Epoch 18:
# Loss=0.00 Batch_ID=781 Accuracy=99.06: 100%|██████████| 782/782 [00:28<00:00, 27.53it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0134, Accuracy: 8329/10000 (83.29%)
#
# Epoch 19:
# Loss=0.09 Batch_ID=781 Accuracy=99.57: 100%|██████████| 782/782 [00:28<00:00, 27.62it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0140, Accuracy: 8318/10000 (83.18%)
#
# Epoch 20:
# Loss=0.03 Batch_ID=781 Accuracy=99.68: 100%|██████████| 782/782 [00:26<00:00, 29.20it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0134, Accuracy: 8462/10000 (84.62%)
#
# Epoch 21:
# Loss=0.35 Batch_ID=781 Accuracy=99.86: 100%|██████████| 782/782 [00:27<00:00, 28.72it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0137, Accuracy: 8433/10000 (84.33%)
#
# Epoch 22:
# Loss=0.12 Batch_ID=781 Accuracy=99.14: 100%|██████████| 782/782 [00:27<00:00, 28.42it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0150, Accuracy: 8350/10000 (83.50%)
#
# Epoch 23:
# Loss=0.08 Batch_ID=781 Accuracy=99.15: 100%|██████████| 782/782 [00:27<00:00, 27.99it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0146, Accuracy: 8264/10000 (82.64%)
#
# Epoch 24:
# Loss=0.04 Batch_ID=781 Accuracy=99.48: 100%|██████████| 782/782 [00:27<00:00, 28.38it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0138, Accuracy: 8370/10000 (83.70%)
#
# Epoch 25:
# Loss=0.00 Batch_ID=781 Accuracy=99.74: 100%|██████████| 782/782 [00:26<00:00, 29.02it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0135, Accuracy: 8421/10000 (84.21%)
#
# Epoch 26:
# Loss=0.00 Batch_ID=781 Accuracy=99.90: 100%|██████████| 782/782 [00:26<00:00, 29.05it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0138, Accuracy: 8427/10000 (84.27%)
#
# Epoch 27:
# Loss=0.01 Batch_ID=781 Accuracy=99.97: 100%|██████████| 782/782 [00:27<00:00, 28.77it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0132, Accuracy: 8530/10000 (85.30%)
#
# Epoch 28:
# Loss=0.00 Batch_ID=781 Accuracy=99.99: 100%|██████████| 782/782 [00:26<00:00, 29.07it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0133, Accuracy: 8540/10000 (85.40%)
#
# Epoch 29:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.38it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0133, Accuracy: 8540/10000 (85.40%)
#
# Epoch 30:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.30it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0133, Accuracy: 8558/10000 (85.58%)
#
# Epoch 31:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.77it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0130, Accuracy: 8574/10000 (85.74%)
#
# Epoch 32:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.72it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0129, Accuracy: 8565/10000 (85.65%)
#
# Epoch 33:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:26<00:00, 29.16it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0132, Accuracy: 8569/10000 (85.69%)
#
# Epoch 34:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.82it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0132, Accuracy: 8562/10000 (85.62%)
#
# Epoch 35:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.50it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0133, Accuracy: 8583/10000 (85.83%)
#
# Epoch 36:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.38it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0132, Accuracy: 8570/10000 (85.70%)
#
# Epoch 37:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.63it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0134, Accuracy: 8574/10000 (85.74%)
#
# Epoch 38:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.64it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0136, Accuracy: 8574/10000 (85.74%)
#
# Epoch 39:
# Loss=0.01 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.81it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0134, Accuracy: 8570/10000 (85.70%)
#
# Epoch 40:
# Loss=0.00 Batch_ID=781 Accuracy=99.99: 100%|██████████| 782/782 [00:27<00:00, 28.58it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0137, Accuracy: 8537/10000 (85.37%)
#
# Epoch 41:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.72it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0136, Accuracy: 8556/10000 (85.56%)
#
# Epoch 42:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.55it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0134, Accuracy: 8537/10000 (85.37%)
#
# Epoch 43:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:26<00:00, 28.98it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0133, Accuracy: 8547/10000 (85.47%)
#
# Epoch 44:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.64it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0134, Accuracy: 8553/10000 (85.53%)
#
# Epoch 45:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.34it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0135, Accuracy: 8545/10000 (85.45%)
#
# Epoch 46:
# Loss=0.00 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.31it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0135, Accuracy: 8552/10000 (85.52%)
#
# Epoch 47:
# Loss=0.01 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.42it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0134, Accuracy: 8572/10000 (85.72%)
#
# Epoch 48:
# Loss=0.07 Batch_ID=781 Accuracy=100.00: 100%|██████████| 782/782 [00:27<00:00, 28.21it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0139, Accuracy: 8537/10000 (85.37%)
#
# Epoch 49:
# Loss=0.01 Batch_ID=781 Accuracy=99.83: 100%|██████████| 782/782 [00:27<00:00, 28.62it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0145, Accuracy: 8456/10000 (84.56%)
#
# Epoch 50:
# Loss=0.00 Batch_ID=781 Accuracy=99.99: 100%|██████████| 782/782 [00:27<00:00, 28.42it/s]
# Validation set: Average loss: 0.0143, Accuracy: 8475/10000 (84.75%)

# %% [markdown]
# ## Plotting Results

# %% [markdown]
# Plot changes in validation loss

# %%
plot_metric(losses, 'Loss')

# %% [markdown]
# Plot changes in validation accuracy

# %%
plot_metric(accuracies, 'Accuracy')

# %% [markdown]
# ## Display Correct and Incorrect Predictions

# %%
save_and_show_result(correct_samples, incorrect_samples, classes)

# %% [markdown]
# ## Result Analysis
#
# Displaying accuracy for each class in the entire validation dataset

# %%
class_level_accuracy(model, val_loader, device, classes)
# Out:
# Accuracy of plane : 89 %
# Accuracy of   car : 93 %
# Accuracy of  bird : 78 %
# Accuracy of   cat : 65 %
# Accuracy of  deer : 83 %
# Accuracy of   dog : 78 %
# Accuracy of  frog : 88 %
# Accuracy of horse : 86 %
# Accuracy of  ship : 92 %
# Accuracy of truck : 90 %
