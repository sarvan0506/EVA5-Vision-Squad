# %% [markdown]
# # Regularization L1, L2, Batch Normalization and Ghost Batch Normalization

# %% [markdown]
# In this experiment we are going to examine the various regularization techniques and their effect on the Neural Networks, we are also going to compare all of the exeriment's result. The dataset used is MNIST hand written digits.

# %%
# Import all necessary libraries

from __future__ import print_function

import lib.model as m         # model class to create CNNs of 8->8->16->pool->16->16->16->gap architecture
import lib.preprocess as pp   # library file that takes care of loading, visualizing, transforming and creating data loaders
import lib.misc as misc       # utility functions for custom graphs and functions

# %% [markdown]
# ### Load the dataset

# %%
data = pp.load_data("MNIST")
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.

# %% [markdown]
# ### Visualize a sample set and calculate mean and std for Image Normalization (transform)

# %%
mean, std = pp.peek(data)

# %% [markdown]
# ### Transform with Image Normalization, Augmentation and create dataloaders

# %%
train_loader, test_loader = pp.transform_load(data, mean, std, batch_size=64)
# Out:
# CUDA Available? True

# %%
# Define dictionary for the experiments

a = {
    "L1 + BN" : ["BN", 0.001, 0],
    "L2 + BN" : ["BN", 0, 0.0001],
    "L1 + L2 + BN" : ["BN", 0.001, 0.0001],
    "GBN" : ["GBN", 0, 0],
    "L1 + L2 + GBN" : ["GBN", 0.001, 0.0001]
}

# %% [markdown]
# ### Run all the experiments

# %%
results = {}

for i in a.items():
    
    print(i[1][0], "L1", i[1][1], "L2", i[1][2])
    
    if i[1][0] == "GBN": train_loader, test_loader = pp.transform_load(data, mean, std, batch_size=16)
    
    res = misc.model_start(train_loader, test_loader, i[1][0], i[1][1], i[1][2], 0.01, 20)
    
    results[i[0]] = res
# Out:
# BN L1 0.001 L2 0
#   0%|          | 0/938 [00:00<?, ?it/s]
# Epoch 1:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Loss=0.54 Batch_ID=937 Accuracy=94.13: 100%|██████████| 938/938 [00:08<00:00, 111.11it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0916, Accuracy: 9765/10000 (97.65%)
#
# Epoch 2:
# Loss=0.39 Batch_ID=937 Accuracy=97.00: 100%|██████████| 938/938 [00:08<00:00, 113.96it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0945, Accuracy: 9773/10000 (97.73%)
#
# Epoch 3:
# Loss=0.39 Batch_ID=937 Accuracy=97.22: 100%|██████████| 938/938 [00:08<00:00, 113.13it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0755, Accuracy: 9794/10000 (97.94%)
#
# Epoch 4:
# Loss=0.57 Batch_ID=937 Accuracy=97.16: 100%|██████████| 938/938 [00:08<00:00, 115.22it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0743, Accuracy: 9782/10000 (97.82%)
#
# Epoch 5:
# Loss=0.34 Batch_ID=937 Accuracy=97.29: 100%|██████████| 938/938 [00:08<00:00, 113.26it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0864, Accuracy: 9788/10000 (97.88%)
#
# Epoch 6:
# Loss=0.22 Batch_ID=937 Accuracy=98.61: 100%|██████████| 938/938 [00:08<00:00, 110.75it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0303, Accuracy: 9917/10000 (99.17%)
#
# Epoch 7:
# Loss=0.21 Batch_ID=937 Accuracy=98.75: 100%|██████████| 938/938 [00:08<00:00, 113.24it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0296, Accuracy: 9916/10000 (99.16%)
#
# Epoch 8:
# Loss=0.19 Batch_ID=937 Accuracy=98.67: 100%|██████████| 938/938 [00:08<00:00, 113.22it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0324, Accuracy: 9902/10000 (99.02%)
#
# Epoch 9:
# Loss=0.30 Batch_ID=937 Accuracy=98.61: 100%|██████████| 938/938 [00:08<00:00, 113.91it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0344, Accuracy: 9917/10000 (99.17%)
#
# Epoch 10:
# Loss=0.17 Batch_ID=937 Accuracy=98.59: 100%|██████████| 938/938 [00:08<00:00, 111.08it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0359, Accuracy: 9896/10000 (98.96%)
#
# Epoch 11:
# Loss=0.20 Batch_ID=937 Accuracy=98.83: 100%|██████████| 938/938 [00:08<00:00, 113.24it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0253, Accuracy: 9940/10000 (99.40%)
#
# Epoch 12:
# Loss=0.23 Batch_ID=937 Accuracy=98.93: 100%|██████████| 938/938 [00:08<00:00, 112.41it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0241, Accuracy: 9943/10000 (99.43%)
#
# Epoch 13:
# Loss=0.26 Batch_ID=937 Accuracy=99.01: 100%|██████████| 938/938 [00:08<00:00, 112.52it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0247, Accuracy: 9935/10000 (99.35%)
#
# Epoch 14:
# Loss=0.19 Batch_ID=937 Accuracy=98.96: 100%|██████████| 938/938 [00:08<00:00, 112.03it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0246, Accuracy: 9935/10000 (99.35%)
#
# Epoch 15:
# Loss=0.15 Batch_ID=937 Accuracy=98.97: 100%|██████████| 938/938 [00:08<00:00, 113.68it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0244, Accuracy: 9934/10000 (99.34%)
#
# Epoch 16:
# Loss=0.15 Batch_ID=937 Accuracy=98.97: 100%|██████████| 938/938 [00:08<00:00, 115.94it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0239, Accuracy: 9941/10000 (99.41%)
#
# Epoch 17:
# Loss=0.20 Batch_ID=937 Accuracy=99.00: 100%|██████████| 938/938 [00:08<00:00, 114.36it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0239, Accuracy: 9935/10000 (99.35%)
#
# Epoch 18:
# Loss=0.16 Batch_ID=937 Accuracy=98.97: 100%|██████████| 938/938 [00:08<00:00, 113.62it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0240, Accuracy: 9934/10000 (99.34%)
#
# Epoch 19:
# Loss=0.17 Batch_ID=937 Accuracy=98.99: 100%|██████████| 938/938 [00:08<00:00, 114.56it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0244, Accuracy: 9932/10000 (99.32%)
#
# Epoch 20:
# Loss=0.19 Batch_ID=937 Accuracy=99.04: 100%|██████████| 938/938 [00:08<00:00, 116.24it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0239, Accuracy: 9935/10000 (99.35%)
#
# BN L1 0 L2 0.0001
# Epoch 1:
# Loss=0.11 Batch_ID=937 Accuracy=94.70: 100%|██████████| 938/938 [00:05<00:00, 166.27it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0789, Accuracy: 9835/10000 (98.35%)
#
# Epoch 2:
# Loss=0.04 Batch_ID=937 Accuracy=97.81: 100%|██████████| 938/938 [00:05<00:00, 166.59it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0544, Accuracy: 9865/10000 (98.65%)
#
# Epoch 3:
# Loss=0.03 Batch_ID=937 Accuracy=98.25: 100%|██████████| 938/938 [00:05<00:00, 170.30it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0368, Accuracy: 9905/10000 (99.05%)
#
# Epoch 4:
# Loss=0.10 Batch_ID=937 Accuracy=98.42: 100%|██████████| 938/938 [00:05<00:00, 167.74it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0341, Accuracy: 9905/10000 (99.05%)
#
# Epoch 5:
# Loss=0.02 Batch_ID=937 Accuracy=98.61: 100%|██████████| 938/938 [00:05<00:00, 166.04it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0296, Accuracy: 9913/10000 (99.13%)
#
# Epoch 6:
# Loss=0.03 Batch_ID=937 Accuracy=98.87: 100%|██████████| 938/938 [00:05<00:00, 161.47it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0227, Accuracy: 9946/10000 (99.46%)
#
# Epoch 7:
# Loss=0.06 Batch_ID=937 Accuracy=99.02: 100%|██████████| 938/938 [00:05<00:00, 167.63it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0218, Accuracy: 9950/10000 (99.50%)
#
# Epoch 8:
# Loss=0.03 Batch_ID=937 Accuracy=99.07: 100%|██████████| 938/938 [00:05<00:00, 165.00it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0218, Accuracy: 9947/10000 (99.47%)
#
# Epoch 9:
# Loss=0.06 Batch_ID=937 Accuracy=99.03: 100%|██████████| 938/938 [00:05<00:00, 167.44it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0223, Accuracy: 9949/10000 (99.49%)
#
# Epoch 10:
# Loss=0.10 Batch_ID=937 Accuracy=99.08: 100%|██████████| 938/938 [00:05<00:00, 164.54it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0215, Accuracy: 9946/10000 (99.46%)
#
# Epoch 11:
# Loss=0.03 Batch_ID=937 Accuracy=99.08: 100%|██████████| 938/938 [00:05<00:00, 166.19it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0213, Accuracy: 9945/10000 (99.45%)
#
# Epoch 12:
# Loss=0.03 Batch_ID=937 Accuracy=99.09: 100%|██████████| 938/938 [00:05<00:00, 163.24it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0211, Accuracy: 9949/10000 (99.49%)
#
# Epoch 13:
# Loss=0.06 Batch_ID=937 Accuracy=99.17: 100%|██████████| 938/938 [00:05<00:00, 168.10it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0217, Accuracy: 9944/10000 (99.44%)
#
# Epoch 14:
# Loss=0.01 Batch_ID=937 Accuracy=99.09: 100%|██████████| 938/938 [00:05<00:00, 172.61it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0210, Accuracy: 9951/10000 (99.51%)
#
# Epoch 15:
# Loss=0.10 Batch_ID=937 Accuracy=99.09: 100%|██████████| 938/938 [00:05<00:00, 168.51it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0205, Accuracy: 9949/10000 (99.49%)
#
# Epoch 16:
# Loss=0.04 Batch_ID=937 Accuracy=99.13: 100%|██████████| 938/938 [00:05<00:00, 169.36it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0218, Accuracy: 9944/10000 (99.44%)
#
# Epoch 17:
# Loss=0.02 Batch_ID=937 Accuracy=99.11: 100%|██████████| 938/938 [00:05<00:00, 166.04it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0206, Accuracy: 9950/10000 (99.50%)
#
# Epoch 18:
# Loss=0.17 Batch_ID=937 Accuracy=99.16: 100%|██████████| 938/938 [00:05<00:00, 169.90it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0213, Accuracy: 9945/10000 (99.45%)
#
# Epoch 19:
# Loss=0.16 Batch_ID=937 Accuracy=99.12: 100%|██████████| 938/938 [00:05<00:00, 167.58it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0216, Accuracy: 9944/10000 (99.44%)
#
# Epoch 20:
# Loss=0.02 Batch_ID=937 Accuracy=99.13: 100%|██████████| 938/938 [00:05<00:00, 167.60it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0204, Accuracy: 9951/10000 (99.51%)
#
# BN L1 0.001 L2 0.0001
# Epoch 1:
# Loss=0.38 Batch_ID=937 Accuracy=94.08: 100%|██████████| 938/938 [00:08<00:00, 111.83it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.1284, Accuracy: 9691/10000 (96.91%)
#
# Epoch 2:
# Loss=0.39 Batch_ID=937 Accuracy=96.97: 100%|██████████| 938/938 [00:08<00:00, 111.83it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0815, Accuracy: 9798/10000 (97.98%)
#
# Epoch 3:
# Loss=0.39 Batch_ID=937 Accuracy=97.18: 100%|██████████| 938/938 [00:08<00:00, 106.53it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.1089, Accuracy: 9714/10000 (97.14%)
#
# Epoch 4:
# Loss=0.28 Batch_ID=937 Accuracy=97.29: 100%|██████████| 938/938 [00:08<00:00, 108.11it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0933, Accuracy: 9743/10000 (97.43%)
#
# Epoch 5:
# Loss=0.31 Batch_ID=937 Accuracy=97.43: 100%|██████████| 938/938 [00:08<00:00, 110.33it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0798, Accuracy: 9783/10000 (97.83%)
#
# Epoch 6:
# Loss=0.31 Batch_ID=937 Accuracy=98.48: 100%|██████████| 938/938 [00:08<00:00, 110.10it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0308, Accuracy: 9919/10000 (99.19%)
#
# Epoch 7:
# Loss=0.22 Batch_ID=937 Accuracy=98.58: 100%|██████████| 938/938 [00:08<00:00, 108.35it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0346, Accuracy: 9913/10000 (99.13%)
#
# Epoch 8:
# Loss=0.21 Batch_ID=937 Accuracy=98.54: 100%|██████████| 938/938 [00:08<00:00, 109.89it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0329, Accuracy: 9911/10000 (99.11%)
#
# Epoch 9:
# Loss=0.17 Batch_ID=937 Accuracy=98.53: 100%|██████████| 938/938 [00:08<00:00, 109.39it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0368, Accuracy: 9900/10000 (99.00%)
#
# Epoch 10:
# Loss=0.22 Batch_ID=937 Accuracy=98.51: 100%|██████████| 938/938 [00:08<00:00, 107.48it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0392, Accuracy: 9905/10000 (99.05%)
#
# Epoch 11:
# Loss=0.28 Batch_ID=937 Accuracy=98.84: 100%|██████████| 938/938 [00:08<00:00, 112.17it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0266, Accuracy: 9929/10000 (99.29%)
#
# Epoch 12:
# Loss=0.20 Batch_ID=937 Accuracy=98.89: 100%|██████████| 938/938 [00:08<00:00, 111.54it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0268, Accuracy: 9928/10000 (99.28%)
#
# Epoch 13:
# Loss=0.15 Batch_ID=937 Accuracy=98.88: 100%|██████████| 938/938 [00:08<00:00, 109.55it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0266, Accuracy: 9925/10000 (99.25%)
#
# Epoch 14:
# Loss=0.16 Batch_ID=937 Accuracy=98.96: 100%|██████████| 938/938 [00:08<00:00, 111.80it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0264, Accuracy: 9931/10000 (99.31%)
#
# Epoch 15:
# Loss=0.14 Batch_ID=937 Accuracy=98.93: 100%|██████████| 938/938 [00:08<00:00, 107.51it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0273, Accuracy: 9923/10000 (99.23%)
#
# Epoch 16:
# Loss=0.30 Batch_ID=937 Accuracy=98.95: 100%|██████████| 938/938 [00:08<00:00, 113.17it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0267, Accuracy: 9926/10000 (99.26%)
#
# Epoch 17:
# Loss=0.14 Batch_ID=937 Accuracy=98.98: 100%|██████████| 938/938 [00:08<00:00, 112.75it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0258, Accuracy: 9928/10000 (99.28%)
#
# Epoch 18:
# Loss=0.14 Batch_ID=937 Accuracy=99.00: 100%|██████████| 938/938 [00:08<00:00, 115.73it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0258, Accuracy: 9925/10000 (99.25%)
#
# Epoch 19:
# Loss=0.17 Batch_ID=937 Accuracy=98.96: 100%|██████████| 938/938 [00:08<00:00, 111.71it/s]
#   0%|          | 0/938 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0262, Accuracy: 9930/10000 (99.30%)
#
# Epoch 20:
# Loss=0.18 Batch_ID=937 Accuracy=98.96: 100%|██████████| 938/938 [00:08<00:00, 116.46it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0255, Accuracy: 9927/10000 (99.27%)
#
# GBN L1 0 L2 0
# CUDA Available? True
# Epoch 1:
# Loss=0.08 Batch_ID=3749 Accuracy=90.47: 100%|██████████| 3750/3750 [00:22<00:00, 166.93it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0495, Accuracy: 9857/10000 (98.57%)
#
# Epoch 2:
# Loss=0.06 Batch_ID=3749 Accuracy=95.19: 100%|██████████| 3750/3750 [00:23<00:00, 162.70it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0417, Accuracy: 9879/10000 (98.79%)
#
# Epoch 3:
# Loss=0.03 Batch_ID=3749 Accuracy=96.13: 100%|██████████| 3750/3750 [00:22<00:00, 164.34it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0391, Accuracy: 9876/10000 (98.76%)
#
# Epoch 4:
# Loss=0.44 Batch_ID=3749 Accuracy=96.50: 100%|██████████| 3750/3750 [00:22<00:00, 170.33it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0333, Accuracy: 9891/10000 (98.91%)
#
# Epoch 5:
# Loss=0.02 Batch_ID=3749 Accuracy=96.78: 100%|██████████| 3750/3750 [00:22<00:00, 165.48it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0290, Accuracy: 9900/10000 (99.00%)
#
# Epoch 6:
# Loss=0.03 Batch_ID=3749 Accuracy=97.27: 100%|██████████| 3750/3750 [00:22<00:00, 166.50it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0249, Accuracy: 9918/10000 (99.18%)
#
# Epoch 7:
# Loss=0.02 Batch_ID=3749 Accuracy=97.50: 100%|██████████| 3750/3750 [00:23<00:00, 161.77it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0233, Accuracy: 9926/10000 (99.26%)
#
# Epoch 8:
# Loss=0.12 Batch_ID=3749 Accuracy=97.53: 100%|██████████| 3750/3750 [00:23<00:00, 161.99it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0241, Accuracy: 9922/10000 (99.22%)
#
# Epoch 9:
# Loss=0.03 Batch_ID=3749 Accuracy=97.61: 100%|██████████| 3750/3750 [00:21<00:00, 171.70it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0226, Accuracy: 9935/10000 (99.35%)
#
# Epoch 10:
# Loss=0.06 Batch_ID=3749 Accuracy=97.61: 100%|██████████| 3750/3750 [00:22<00:00, 164.88it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0242, Accuracy: 9928/10000 (99.28%)
#
# Epoch 11:
# Loss=0.02 Batch_ID=3749 Accuracy=97.66: 100%|██████████| 3750/3750 [00:22<00:00, 164.50it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0234, Accuracy: 9923/10000 (99.23%)
#
# Epoch 12:
# Loss=0.15 Batch_ID=3749 Accuracy=97.75: 100%|██████████| 3750/3750 [00:22<00:00, 170.11it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0233, Accuracy: 9930/10000 (99.30%)
#
# Epoch 13:
# Loss=0.06 Batch_ID=3749 Accuracy=97.75: 100%|██████████| 3750/3750 [00:22<00:00, 164.33it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0231, Accuracy: 9928/10000 (99.28%)
#
# Epoch 14:
# Loss=0.03 Batch_ID=3749 Accuracy=97.69: 100%|██████████| 3750/3750 [00:22<00:00, 164.06it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0230, Accuracy: 9935/10000 (99.35%)
#
# Epoch 15:
# Loss=0.01 Batch_ID=3749 Accuracy=97.64: 100%|██████████| 3750/3750 [00:22<00:00, 165.36it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0235, Accuracy: 9933/10000 (99.33%)
#
# Epoch 16:
# Loss=0.06 Batch_ID=3749 Accuracy=97.73: 100%|██████████| 3750/3750 [00:22<00:00, 164.27it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0235, Accuracy: 9928/10000 (99.28%)
#
# Epoch 17:
# Loss=0.07 Batch_ID=3749 Accuracy=97.61: 100%|██████████| 3750/3750 [00:22<00:00, 167.03it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0233, Accuracy: 9934/10000 (99.34%)
#
# Epoch 18:
# Loss=0.04 Batch_ID=3749 Accuracy=97.67: 100%|██████████| 3750/3750 [00:23<00:00, 161.77it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0231, Accuracy: 9932/10000 (99.32%)
#
# Epoch 19:
# Loss=0.02 Batch_ID=3749 Accuracy=97.64: 100%|██████████| 3750/3750 [00:22<00:00, 164.28it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0221, Accuracy: 9932/10000 (99.32%)
#
# Epoch 20:
# Loss=0.04 Batch_ID=3749 Accuracy=97.63: 100%|██████████| 3750/3750 [00:22<00:00, 166.24it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0229, Accuracy: 9933/10000 (99.33%)
#
# GBN L1 0.001 L2 0.0001
# CUDA Available? True
# Epoch 1:
# Loss=0.61 Batch_ID=3749 Accuracy=88.53: 100%|██████████| 3750/3750 [00:35<00:00, 106.88it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.1105, Accuracy: 9676/10000 (96.76%)
#
# Epoch 2:
# Loss=0.58 Batch_ID=3749 Accuracy=91.99: 100%|██████████| 3750/3750 [00:35<00:00, 105.00it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.1292, Accuracy: 9611/10000 (96.11%)
#
# Epoch 3:
# Loss=0.49 Batch_ID=3749 Accuracy=92.25: 100%|██████████| 3750/3750 [00:35<00:00, 106.52it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.1194, Accuracy: 9621/10000 (96.21%)
#
# Epoch 4:
# Loss=0.88 Batch_ID=3749 Accuracy=92.36: 100%|██████████| 3750/3750 [00:34<00:00, 108.01it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.1093, Accuracy: 9662/10000 (96.62%)
#
# Epoch 5:
# Loss=0.43 Batch_ID=3749 Accuracy=92.59: 100%|██████████| 3750/3750 [00:35<00:00, 106.75it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0883, Accuracy: 9748/10000 (97.48%)
#
# Epoch 6:
# Loss=0.36 Batch_ID=3749 Accuracy=95.25: 100%|██████████| 3750/3750 [00:35<00:00, 105.89it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0423, Accuracy: 9874/10000 (98.74%)
#
# Epoch 7:
# Loss=0.36 Batch_ID=3749 Accuracy=95.57: 100%|██████████| 3750/3750 [00:35<00:00, 106.35it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0425, Accuracy: 9862/10000 (98.62%)
#
# Epoch 8:
# Loss=0.43 Batch_ID=3749 Accuracy=95.43: 100%|██████████| 3750/3750 [00:35<00:00, 107.06it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0472, Accuracy: 9859/10000 (98.59%)
#
# Epoch 9:
# Loss=0.29 Batch_ID=3749 Accuracy=95.42: 100%|██████████| 3750/3750 [00:35<00:00, 106.20it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0467, Accuracy: 9844/10000 (98.44%)
#
# Epoch 10:
# Loss=0.33 Batch_ID=3749 Accuracy=95.24: 100%|██████████| 3750/3750 [00:35<00:00, 105.25it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0442, Accuracy: 9859/10000 (98.59%)
#
# Epoch 11:
# Loss=0.28 Batch_ID=3749 Accuracy=96.33: 100%|██████████| 3750/3750 [00:35<00:00, 107.06it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0349, Accuracy: 9898/10000 (98.98%)
#
# Epoch 12:
# Loss=0.49 Batch_ID=3749 Accuracy=96.46: 100%|██████████| 3750/3750 [00:34<00:00, 107.82it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0365, Accuracy: 9891/10000 (98.91%)
#
# Epoch 13:
# Loss=0.37 Batch_ID=3749 Accuracy=96.61: 100%|██████████| 3750/3750 [00:34<00:00, 107.71it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0345, Accuracy: 9895/10000 (98.95%)
#
# Epoch 14:
# Loss=0.24 Batch_ID=3749 Accuracy=96.46: 100%|██████████| 3750/3750 [00:34<00:00, 107.83it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0338, Accuracy: 9906/10000 (99.06%)
#
# Epoch 15:
# Loss=0.20 Batch_ID=3749 Accuracy=96.53: 100%|██████████| 3750/3750 [00:34<00:00, 107.44it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0380, Accuracy: 9888/10000 (98.88%)
#
# Epoch 16:
# Loss=0.36 Batch_ID=3749 Accuracy=96.58: 100%|██████████| 3750/3750 [00:34<00:00, 107.93it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0330, Accuracy: 9901/10000 (99.01%)
#
# Epoch 17:
# Loss=0.29 Batch_ID=3749 Accuracy=96.62: 100%|██████████| 3750/3750 [00:34<00:00, 108.97it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0337, Accuracy: 9904/10000 (99.04%)
#
# Epoch 18:
# Loss=0.26 Batch_ID=3749 Accuracy=96.72: 100%|██████████| 3750/3750 [00:34<00:00, 109.69it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0326, Accuracy: 9906/10000 (99.06%)
#
# Epoch 19:
# Loss=0.22 Batch_ID=3749 Accuracy=96.61: 100%|██████████| 3750/3750 [00:34<00:00, 108.78it/s]
#   0%|          | 0/3750 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0319, Accuracy: 9911/10000 (99.11%)
#
# Epoch 20:
# Loss=0.45 Batch_ID=3749 Accuracy=96.68: 100%|██████████| 3750/3750 [00:34<00:00, 109.96it/s]
# Validation set: Average loss: 0.0334, Accuracy: 9905/10000 (99.05%)

# %% [markdown]
# ### Plot validation accuracy and Losses for all the experiments

# %%
misc.plot(results, "accuracy")

# %%
misc.plot(results, "loss")

# %% [markdown]
# ### Plotting missclassified images for L1 + L2 + BGN

# %%
misc.missclassified(results, "L1 + L2 + GBN")
