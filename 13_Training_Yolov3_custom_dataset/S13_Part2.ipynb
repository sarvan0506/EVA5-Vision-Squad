# %% [markdown]
# # Inferencing with COCO YOLO v3

# %% [markdown]
# ## Import necessary libraries

# %%
import time
import glob
import torch
from PIL import Image
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.1 _CudaDeviceProperties(name='GeForce GTX 1080 Ti', major=6, minor=1, total_memory=11176MB, multi_processor_count=28)

# %%
# Move into the YoloV3 dir
cd YoloV3
# Out:
# /src/D/Research/EVA5-Vision-Squad/S13/YoloV3

# %% [markdown]
# ## Train the model with  custom data for 300 epochs

# %%
# !python3.6 train.py --data data/customdata/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 300
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='GeForce GTX 1080 Ti', total_memory=11176MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3028 found, 128 missing, 38 empty, 0 duplicate, for 3194 images)
# Caching images (1.8GB): 100%|##############| 3194/3194 [00:14<00:00, 227.94it/s]
# Caching labels (297 found, 14 missing, 7 empty, 0 duplicate, for 318 images): 10
# Caching images (0.1GB): 100%|################| 318/318 [00:02<00:00, 149.50it/s]
# Image sizes 512 - 512 train, 512 test
# Using 8 dataloader workers
# Starting training for 300 epochs...
#
# ...

# %% [markdown]
# ## Detect Bounding Boxes with the trained dataset

# %%
# !python3.6 detect.py --source source --conf-thres 0.1 --output output
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='source', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='GeForce GTX 1080 Ti', total_memory=11176MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/1739 source/img001.jpg: 320x512 1 hardhats, 1 vests, Done. (0.014s)
# image 2/1739 source/img002.jpg: 320x512 1 hardhats, 1 vests, Done. (0.014s)
# image 3/1739 source/img003.jpg: 320x512 1 hardhats, 1 vests, Done. (0.014s)
# image 4/1739 source/img004.jpg: 320x512 1 hardhats, 1 vests, Done. (0.014s)
# image 5/1739 source/img005.jpg: 320x512 1 hardhats, 1 vests, Done. (0.014s)
# image 6/1739 source/img006.jpg: 320x512 1 hardhats, 1 vests, Done. (0.014s)
# ...

# %% [markdown]
# ## Some sample frames with Bounding Boxes

# %%
Image(filename='YoloV3/output/img702.jpg', width=800)

# %%
from IPython.display import Image, clear_output 
Image(filename='YoloV3/output/img1419.jpg', width=800)

# %%
Image(filename='YoloV3/output/img1773.jpg', width=800)
