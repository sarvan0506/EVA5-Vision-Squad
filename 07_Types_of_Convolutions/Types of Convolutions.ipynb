# %% [markdown]
# ### In this exercise we are going to look into different type of convolutions

# %%
# import all necessary libraries
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from cuda import initialize_cuda
from result import class_level_accuracy, plot_metric, save_and_show_result
from model.train import train
from model.evaluate import val
from model.network import Net
from model.utils import cross_entropy_loss, sgd_optimizer, model_summary
from data.dataset import cifar10_dataset, cifar10_classes
from data.downloader import download_cifar10

# %% [markdown]
# ### Initialize variables inside a class

# %%
class Args:

    # Data Loading
    # ============

    train_batch_size = 64
    val_batch_size = 64
    num_workers = 4

    # Regularization
    # ==============
    dropout = 0.1

    # Training
    # ========
    random_seed = 1
    epochs = 25
    learning_rate = 0.01
    momentum = 0.9

# %% [markdown]
# #### Using CIFAR10 dataset

# %%
# Download data
cifar_dataset = download_cifar10()
classes = cifar10_classes()
sample_data, sample_targets = cifar_dataset.data, cifar_dataset.targets

# Get image size
image_size = np.transpose(sample_data[0], (2, 0, 1)).shape

# Set number of images to display
num_images = 4

# Display images with labels
fig, axs = plt.subplots(1, 4, figsize=(8, 8))
fig.tight_layout()

for i in range(num_images):
    axs[i].axis('off')
    axs[i].set_title(f'Label: {classes[sample_targets[i]]}')
    axs[i].imshow(sample_data[i])
# Out:
# Files already downloaded and verified

# %% [markdown]
# ### Initialize GPU

# %%
# Initialize CUDA and set random seed
cuda, device = initialize_cuda(Args.random_seed)
# Out:
# GPU Available? True

# %% [markdown]
# ### Creating train and test data loaders

# %%
# Create train data loader
train_loader = cifar10_dataset(
    Args.train_batch_size, cuda, Args.num_workers, train=True
)

# Create val data loader
val_loader = cifar10_dataset(
    Args.val_batch_size, cuda, Args.num_workers, train=False
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Creating model from the Net class

# %%
model = Net(Args.dropout).to(device)  # Create model
model_summary(model, image_size)  # Display model summary
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             896
#               ReLU-2           [-1, 32, 32, 32]               0
#        BatchNorm2d-3           [-1, 32, 32, 32]              64
#            Dropout-4           [-1, 32, 32, 32]               0
#             Conv2d-5           [-1, 64, 32, 32]          18,496
#               ReLU-6           [-1, 64, 32, 32]               0
#        BatchNorm2d-7           [-1, 64, 32, 32]             128
#            Dropout-8           [-1, 64, 32, 32]               0
#          MaxPool2d-9           [-1, 64, 16, 16]               0
#            Conv2d-10           [-1, 32, 16, 16]           2,080
#            Conv2d-11           [-1, 32, 16, 16]           9,248
#              ReLU-12           [-1, 32, 16, 16]               0
#       BatchNorm2d-13           [-1, 32, 16, 16]              64
#           Dropout-14           [-1, 32, 16, 16]               0
#            Conv2d-15           [-1, 64, 16, 16]          18,496
#              ReLU-16           [-1, 64, 16, 16]               0
#       BatchNorm2d-17           [-1, 64, 16, 16]             128
#           Dropout-18           [-1, 64, 16, 16]               0
#         MaxPool2d-19             [-1, 64, 8, 8]               0
#            Conv2d-20             [-1, 32, 8, 8]           2,080
#            Conv2d-21             [-1, 32, 8, 8]           9,248
#              ReLU-22             [-1, 32, 8, 8]               0
#       BatchNorm2d-23             [-1, 32, 8, 8]              64
#           Dropout-24             [-1, 32, 8, 8]               0
#            Conv2d-25             [-1, 32, 8, 8]             320
#            Conv2d-26             [-1, 64, 8, 8]           2,112
#              ReLU-27             [-1, 64, 8, 8]               0
#       BatchNorm2d-28             [-1, 64, 8, 8]             128
#           Dropout-29             [-1, 64, 8, 8]               0
#         MaxPool2d-30             [-1, 64, 4, 4]               0
#            Conv2d-31             [-1, 32, 4, 4]           2,080
#            Conv2d-32             [-1, 32, 4, 4]           9,248
#              ReLU-33             [-1, 32, 4, 4]               0
#       BatchNorm2d-34             [-1, 32, 4, 4]              64
#           Dropout-35             [-1, 32, 4, 4]               0
#            Conv2d-36             [-1, 64, 2, 2]          18,496
#              ReLU-37             [-1, 64, 2, 2]               0
#       BatchNorm2d-38             [-1, 64, 2, 2]             128
#           Dropout-39             [-1, 64, 2, 2]               0
# AdaptiveAvgPool2d-40             [-1, 64, 1, 1]               0
#            Linear-41                   [-1, 10]             650
# ================================================================
# Total params: 94,218
# Trainable params: 94,218
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.22
# Params size (MB): 0.36
# Estimated Total Size (MB): 4.59
# ----------------------------------------------------------------
# None

# %% [markdown]
# ### Training the model for 25 epochs

# %%
losses = []
accuracies = []
incorrect_samples = []

criterion = cross_entropy_loss()  # Create loss function
optimizer = sgd_optimizer(model, Args.learning_rate, Args.momentum)  # Create optimizer

for epoch in range(1, Args.epochs + 1):
    print(f'Epoch {epoch}:')
    train(model, train_loader, device, optimizer, criterion)
    val(model, val_loader, device, criterion, losses, accuracies, incorrect_samples)
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# Epoch 1:
# Loss=0.91 Batch_ID=781 Accuracy=50.58: 100%|██████████| 782/782 [00:06<00:00, 120.11it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0181, Accuracy: 5880/10000 (58.80%)
#
# Epoch 2:
# Loss=1.25 Batch_ID=781 Accuracy=65.36: 100%|██████████| 782/782 [00:06<00:00, 119.04it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0142, Accuracy: 6787/10000 (67.87%)
#
# Epoch 3:
# Loss=0.62 Batch_ID=781 Accuracy=70.54: 100%|██████████| 782/782 [00:06<00:00, 120.82it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0123, Accuracy: 7242/10000 (72.42%)
#
# Epoch 4:
# Loss=0.76 Batch_ID=781 Accuracy=74.01: 100%|██████████| 782/782 [00:06<00:00, 119.46it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0108, Accuracy: 7616/10000 (76.16%)
#
# Epoch 5:
# Loss=0.49 Batch_ID=781 Accuracy=75.98: 100%|██████████| 782/782 [00:06<00:00, 119.74it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0104, Accuracy: 7724/10000 (77.24%)
#
# Epoch 6:
# Loss=0.67 Batch_ID=781 Accuracy=77.46: 100%|██████████| 782/782 [00:06<00:00, 117.81it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0100, Accuracy: 7827/10000 (78.27%)
#
# Epoch 7:
# Loss=0.35 Batch_ID=781 Accuracy=78.83: 100%|██████████| 782/782 [00:06<00:00, 121.26it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0103, Accuracy: 7717/10000 (77.17%)
#
# Epoch 8:
# Loss=0.57 Batch_ID=781 Accuracy=79.73: 100%|██████████| 782/782 [00:06<00:00, 118.40it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0095, Accuracy: 7935/10000 (79.35%)
#
# Epoch 9:
# Loss=0.74 Batch_ID=781 Accuracy=80.74: 100%|██████████| 782/782 [00:06<00:00, 119.00it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0091, Accuracy: 8034/10000 (80.34%)
#
# Epoch 10:
# Loss=0.19 Batch_ID=781 Accuracy=81.57: 100%|██████████| 782/782 [00:06<00:00, 118.26it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0085, Accuracy: 8154/10000 (81.54%)
#
# Epoch 11:
# Loss=0.67 Batch_ID=781 Accuracy=81.99: 100%|██████████| 782/782 [00:06<00:00, 119.13it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0086, Accuracy: 8130/10000 (81.30%)
#
# Epoch 12:
# Loss=0.22 Batch_ID=781 Accuracy=82.62: 100%|██████████| 782/782 [00:06<00:00, 117.04it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0086, Accuracy: 8148/10000 (81.48%)
#
# Epoch 13:
# Loss=0.55 Batch_ID=781 Accuracy=83.22: 100%|██████████| 782/782 [00:06<00:00, 116.41it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0088, Accuracy: 8108/10000 (81.08%)
#
# Epoch 14:
# Loss=0.81 Batch_ID=781 Accuracy=83.29: 100%|██████████| 782/782 [00:06<00:00, 119.19it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0089, Accuracy: 8092/10000 (80.92%)
#
# Epoch 15:
# Loss=0.80 Batch_ID=781 Accuracy=83.88: 100%|██████████| 782/782 [00:06<00:00, 121.69it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0086, Accuracy: 8187/10000 (81.87%)
#
# Epoch 16:
# Loss=0.98 Batch_ID=781 Accuracy=84.27: 100%|██████████| 782/782 [00:06<00:00, 119.66it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0082, Accuracy: 8226/10000 (82.26%)
#
# Epoch 17:
# Loss=0.74 Batch_ID=781 Accuracy=84.88: 100%|██████████| 782/782 [00:06<00:00, 120.45it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0082, Accuracy: 8242/10000 (82.42%)
#
# Epoch 18:
# Loss=0.46 Batch_ID=781 Accuracy=85.20: 100%|██████████| 782/782 [00:06<00:00, 117.71it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0083, Accuracy: 8185/10000 (81.85%)
#
# Epoch 19:
# Loss=0.58 Batch_ID=781 Accuracy=85.22: 100%|██████████| 782/782 [00:06<00:00, 117.79it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0083, Accuracy: 8250/10000 (82.50%)
#
# Epoch 20:
# Loss=0.34 Batch_ID=781 Accuracy=85.39: 100%|██████████| 782/782 [00:06<00:00, 118.18it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0081, Accuracy: 8271/10000 (82.71%)
#
# Epoch 21:
# Loss=0.55 Batch_ID=781 Accuracy=86.03: 100%|██████████| 782/782 [00:06<00:00, 117.59it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0080, Accuracy: 8299/10000 (82.99%)
#
# Epoch 22:
# Loss=1.20 Batch_ID=781 Accuracy=86.10: 100%|██████████| 782/782 [00:06<00:00, 115.09it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0082, Accuracy: 8270/10000 (82.70%)
#
# Epoch 23:
# Loss=0.35 Batch_ID=781 Accuracy=86.53: 100%|██████████| 782/782 [00:06<00:00, 119.05it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0079, Accuracy: 8350/10000 (83.50%)
#
# Epoch 24:
# Loss=0.59 Batch_ID=781 Accuracy=86.82: 100%|██████████| 782/782 [00:06<00:00, 117.11it/s]
#   0%|          | 0/782 [00:00<?, ?it/s]
# Validation set: Average loss: 0.0081, Accuracy: 8301/10000 (83.01%)
#
# Epoch 25:
# Loss=0.40 Batch_ID=781 Accuracy=87.00: 100%|██████████| 782/782 [00:06<00:00, 116.80it/s]
# Validation set: Average loss: 0.0084, Accuracy: 8238/10000 (82.38%)

# %% [markdown]
# ### Plot the validation loss

# %%
plot_metric(losses, 'Loss')

# %% [markdown]
# ### Plot the validation accuracy

# %%
plot_metric(accuracies, 'Accuracy')

# %% [markdown]
# ### Display 25 missclassified images by the model

# %%
save_and_show_result(incorrect_samples, classes)

# %% [markdown]
# ### Accuracy of individual classes

# %%
class_level_accuracy(model, val_loader, device, classes)
# Out:
# Accuracy of plane : 90 %
# Accuracy of   car : 88 %
# Accuracy of  bird : 61 %
# Accuracy of   cat : 69 %
# Accuracy of  deer : 82 %
# Accuracy of   dog : 68 %
# Accuracy of  frog : 93 %
# Accuracy of horse : 84 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 90 %
